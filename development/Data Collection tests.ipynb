# %%
from config import API_KEY

from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators

import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
ts = TimeSeries(key=API_KEY, output_format='pandas')
ti = TechIndicators(key=API_KEY, output_format='pandas')

# %%
ntnx, meta_data = ts.get_intraday('NTNX', interval='15min', outputsize='compact')

# %%
ntnx.sort_index(ascending=True, inplace=True)

# If converting to datetime
# For some reason, the plot funciton did not work as well on datetime
# ntnx.index = pd.to_datetime(ntnx.index)

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (15min) open, high, low, close prices and volume',
#  '2. Symbol': 'NTNX',
#  '3. Last Refreshed': '2019-09-09 16:00:00',
#  '4. Interval': '15min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
ntnx.head()
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2019-09-04 10:45:00  23.5704   23.585  23.475   23.5204    88546.0
# 2019-09-04 11:00:00  23.5200   23.540  23.370   23.3700   101067.0
# 2019-09-04 11:15:00  23.3900   23.560  23.380   23.4500   156441.0
# 2019-09-04 11:30:00  23.4400   23.545  23.400   23.5000    88915.0
# 2019-09-04 11:45:00  23.4908   23.560  23.440   23.4708    54977.0

# %% [markdown]
# ### This would be a good time to rename the columns with:
# `.rename(columns={"1. open": "open", etc})` <br>
# In this notebook, it's done at a later time

# %%
ntnx_vol = ntnx['5. volume']

# %%
ntnx.drop(columns='5. volume', inplace=True)

# %%
ntnx.plot()

# %%
ntnx_vol.plot()

# %%
# # If collecting RSI data

# rsi, rsi_meta = ti.get_rsi('NTNX', interval='15min', time_period=7, series_type='close')

# # rsi.index = pd.to_datetime(rsi.index)

# # Match index range to the ntnx data
# rsi = rsi[rsi.index >= '2019-08-27 10:45']

# rsi.plot()

# %% [markdown]
# ## The smas are based on the closing price

# %%
sma8, sma8_meta = ti.get_sma('NTNX', interval='15min', time_period=8, series_type='close')
sma13, sma13_meta = ti.get_sma('NTNX', interval='15min', time_period=13, series_type='close')

# %%
# Match index range to the ntnx data

sma8 = sma8[sma8.index >= '2019-08-27 10:45']
sma13 = sma13[sma13.index >= '2019-08-27 10:45']

# %%
sma8.head()
# Out:
#                       SMA
# date
# 2019-08-27 10:45  19.7310
# 2019-08-27 11:00  19.7509
# 2019-08-27 11:15  19.7402
# 2019-08-27 11:30  19.7019
# 2019-08-27 11:45  19.6293

# %%
sma13.head()
# Out:
#                       SMA
# date
# 2019-08-27 10:45  19.6065
# 2019-08-27 11:00  19.6334
# 2019-08-27 11:15  19.6368
# 2019-08-27 11:30  19.6301
# 2019-08-27 11:45  19.6201

# %%
smas = sma8.join(sma13, lsuffix='_8', rsuffix='_13')

# %%
type(smas.index)
# Out:
# pandas.core.indexes.base.Index

# %%
# smas.index = pd.to_datetime(smas.index)

# %%
smas.head()
# Out:
#                     SMA_8   SMA_13
# date
# 2019-08-27 10:45  19.7310  19.6065
# 2019-08-27 11:00  19.7509  19.6334
# 2019-08-27 11:15  19.7402  19.6368
# 2019-08-27 11:30  19.7019  19.6301
# 2019-08-27 11:45  19.6293  19.6201

# %%
smas.plot()

# %%
# Remove last 3 characters from index string
# So the index matches smas
ntnx.index = ntnx.index.map(lambda x: x[:-3])

# %%
# If Joining to RSI
# full = ntnx.join(smas).join(rsi)

# %% [markdown]
# ## Joining the price info with the indicator columns, and then creating a column to track relation of SMA 8 and 13

# %% [markdown]
# ### This would be a good time to rename the columns with:
# `.rename(columns={"1. open": "open", etc})` <br>
# In this notebook, it's done at a later time

# %%
test_smas = ntnx.join(smas)

# %%
test_smas['8<13'] = test_smas.SMA_8<test_smas.SMA_13

# %%
test_smas.head()
# Out:
#                date  1. open  2. high  3. low  4. close    SMA_8   SMA_13  \
# 0  2019-09-04 10:45  23.5704   23.585  23.475   23.5204  23.3250  23.1548
# 1  2019-09-04 11:00  23.5200   23.540  23.370   23.3700  23.3943  23.1894
# 2  2019-09-04 11:15  23.3900   23.560  23.380   23.4500  23.4742  23.2289
# 3  2019-09-04 11:30  23.4400   23.545  23.400   23.5000  23.5530  23.2750
# 4  2019-09-04 11:45  23.4908   23.560  23.440   23.4708  23.5328  23.3220
#
#     8<13  Buy
# 0  False    0
# 1  False    0
# 2  False    0
# 3  False    0
# 4  False    0

# %%
# 2019-09-05 10:00 is where the first buy signal should be

# %%
# Reset index so we can use the integer index values later
test_smas.reset_index(inplace=True)
test_smas.head()
# Out:
#                date  1. open  2. high  3. low  4. close    SMA_8   SMA_13  \
# 0  2019-09-04 10:45  23.5704   23.585  23.475   23.5204  23.3250  23.1548
# 1  2019-09-04 11:00  23.5200   23.540  23.370   23.3700  23.3943  23.1894
# 2  2019-09-04 11:15  23.3900   23.560  23.380   23.4500  23.4742  23.2289
# 3  2019-09-04 11:30  23.4400   23.545  23.400   23.5000  23.5530  23.2750
# 4  2019-09-04 11:45  23.4908   23.560  23.440   23.4708  23.5328  23.3220
#
#     8<13  Buy
# 0  False    0
# 1  False    0
# 2  False    0
# 3  False    0
# 4  False    0

# %% [markdown]
# ## Setting the trigger in the 'Buy' column

# %%
test_smas['Buy'] = 0

# Starting on index 2, so we can reference the two previous rows
# If sma8 < sma13 two rows ago, and sma8 > sma13 1 row ago,
# indicate "buy" on current row

for i in range(2, len(test_smas)+1):
    if (test_smas.loc[i-2, '8<13']) and (test_smas.loc[i-1, '8<13'] == False):
        test_smas.loc[i, 'Buy'] = 1

# %%
test_smas.head(30)
# Out:
#                 date  1. open  2. high   3. low  4. close    SMA_8   SMA_13  \
# 0   2019-09-04 10:45  23.5704  23.5850  23.4750   23.5204  23.3250  23.1548
# 1   2019-09-04 11:00  23.5200  23.5400  23.3700   23.3700  23.3943  23.1894
# 2   2019-09-04 11:15  23.3900  23.5600  23.3800   23.4500  23.4742  23.2289
# 3   2019-09-04 11:30  23.4400  23.5450  23.4000   23.5000  23.5530  23.2750
# 4   2019-09-04 11:45  23.4908  23.5600  23.4400   23.4708  23.5328  23.3220
# 5   2019-09-04 12:00  23.4500  23.5150  23.4100   23.4700  23.4978  23.3739
# 6   2019-09-04 12:15  23.4500  23.4950  23.4150   23.4200  23.4715  23.4204
# 7   2019-09-04 12:30  23.4106  23.4600  23.3700   23.4406  23.4552  23.4689
# 8   2019-09-04 12:45  23.4510  23.4600  23.3243   23.3810  23.4378  23.5082
# 9   2019-09-04 13:00  23.3800  23.5000  23.3700   23.4600  23.4491  23.4949
# 10  2019-09-04 13:15  23.4650  23.5000  23.4200   23.4200  23.4453  23.4695
# 11  2019-09-04 13:30  23.4255  23.4400  23.3200   23.4055  23.4335  23.4522
# 12  2019-09-04 13:45  23.4000  23.4000  23.1900   23.2050  23.4003  23.4241
# 13  2019-09-04 14:00  23.2100  23.2200  23.1400   23.2000  23.3665  23.3995
# 14  2019-09-04 14:15  23.2000  23.2050  23.1100   23.1100  23.3278  23.3795
# 15  2019-09-04 14:30  23.1100  23.3100  23.1050   23.2850  23.3083  23.3668
# 16  2019-09-04 14:45  23.2857  23.3450  23.2266   23.2752  23.2951  23.3495
# 17  2019-09-04 15:00  23.2700  23.2850  23.1900   23.2300  23.2663  23.3309
# 18  2019-09-04 15:15  23.2310  23.3124  23.1823   23.2810  23.2490  23.3164
# 19  2019-09-04 15:30  23.2708  23.2800  23.2050   23.2508  23.2296  23.3034
# 20  2019-09-04 15:45  23.2500  23.4500  23.2450   23.3450  23.2471  23.2960
# 21  2019-09-04 16:00  23.3400  23.3450  23.2700   23.3300  23.2634  23.2921
# 22  2019-09-05 09:45  24.1409  24.6929  24.0523   24.6309  23.4535  23.3822
# 23  2019-09-05 10:00  24.6300  24.6400  24.4300   24.5400  23.6104  23.4683
# 24  2019-09-05 10:15  24.5500  24.7700  24.4000   24.4000  23.7510  23.5448
# 25  2019-09-05 10:30  24.4050  24.4100  24.1800   24.1800  23.8697  23.6198
# 26  2019-09-05 10:45  24.1708  24.2800  24.1550   24.1808  23.9822  23.6953
# 27  2019-09-05 11:00  24.1800  24.3200  23.8700   23.8900  24.0621  23.7553
# 28  2019-09-05 11:15  23.8909  24.1925  23.8722   24.1559  24.1634  23.8223
# 29  2019-09-05 11:30  24.1556  24.1900  24.0466   24.1006  24.2598  23.8858
#
#      8<13  Buy
# 0   False    0
# 1   False    0
# 2   False    0
# 3   False    0
# 4   False    0
# 5   False    0
# 6   False    0
# 7    True    0
# 8    True    0
# 9    True    0
# 10   True    0
# 11   True    0
# 12   True    0
# 13   True    0
# 14   True    0
# 15   True    0
# 16   True    0
# 17   True    0
# 18   True    0
# 19   True    0
# 20   True    0
# 21   True    0
# 22  False    0
# 23  False    1
# 24  False    0
# 25  False    0
# 26  False    0
# 27  False    0
# 28  False    0
# 29  False    0

# %% [markdown]
# ### Rename columns to remove spaces, as well as rename DataFrame

# %%
smas = test_smas.rename(columns={"1. open": "open",
                                 "2. high": "high",
                                 "3. low": "low",
                                 "4. close": "close"})

# %%
# Get indexes where Buy is 1 (True)
buy_idxs = smas.index[smas['Buy']==1].tolist()
buy_idxs
# Out:
# [23, 42, 57, 75]

# %% [markdown]
# ### Logic to enter a trade at open price and monitor for upper and lower bound triggers on this row and subsequent rows

# %%
# This creates an empty column that can accept tuples/lists
smas["W/L"] = pd.Series(dtype=object)

# Returns tuple of W or L plus the index where the trade was closed
for idx in buy_idxs:
    purch_price = smas.loc[idx, 'open']
    upper_lim = purch_price * 1.01
    lower_lim = purch_price * 0.997
    for i in range(idx, len(smas)+1):
        if (smas.loc[i, ["high", "low", "close"]]<=lower_lim).any():
            smas.at[idx, "W/L"] = ("L", i)
            break
        elif (smas.loc[i, ["high", "low", "close"]]>=upper_lim).any():
            smas.at[idx, "W/L"] = ("W", i)
            break
        elif i == len(smas):
            break

# %%
# Explore the columns containing buy signals
smas.loc[20:77]
# Out:
#                 date     open     high      low    close    SMA_8   SMA_13  \
# 20  2019-09-04 15:45  23.2500  23.4500  23.2450  23.3450  23.2471  23.2960
# 21  2019-09-04 16:00  23.3400  23.3450  23.2700  23.3300  23.2634  23.2921
# 22  2019-09-05 09:45  24.1409  24.6929  24.0523  24.6309  23.4535  23.3822
# 23  2019-09-05 10:00  24.6300  24.6400  24.4300  24.5400  23.6104  23.4683
# 24  2019-09-05 10:15  24.5500  24.7700  24.4000  24.4000  23.7510  23.5448
# 25  2019-09-05 10:30  24.4050  24.4100  24.1800  24.1800  23.8697  23.6198
# 26  2019-09-05 10:45  24.1708  24.2800  24.1550  24.1808  23.9822  23.6953
# 27  2019-09-05 11:00  24.1800  24.3200  23.8700  23.8900  24.0621  23.7553
# 28  2019-09-05 11:15  23.8909  24.1925  23.8722  24.1559  24.1634  23.8223
# 29  2019-09-05 11:30  24.1556  24.1900  24.0466  24.1006  24.2598  23.8858
# 30  2019-09-05 11:45  24.1099  24.1350  24.0500  24.0600  24.1884  23.9496
# 31  2019-09-05 12:00  24.0400  24.0500  23.9450  23.9700  24.1172  24.0026
# 32  2019-09-05 12:15  23.9904  23.9950  23.9200  23.9404  24.0597  24.0557
# 33  2019-09-05 12:30  23.9455  24.0200  23.8550  23.8600  24.0197  24.0953
# 34  2019-09-05 12:45  23.8560  23.9400  23.8396  23.9260  23.9879  24.1411
# 35  2019-09-05 13:00  23.9200  24.0800  23.9200  24.0000  24.0016  24.0926
# 36  2019-09-05 13:15  24.0000  24.0700  24.0000  24.0150  23.9840  24.0522
# 37  2019-09-05 13:30  24.0150  24.1100  24.0100  24.1050  23.9845  24.0295
# 38  2019-09-05 13:45  24.1000  24.1200  24.0600  24.0700  23.9858  24.0211
# 39  2019-09-05 14:00  24.0700  24.1300  24.0700  24.1000  24.0020  24.0148
# 40  2019-09-05 14:15  24.0950  24.2300  24.0950  24.2000  24.0345  24.0387
# 41  2019-09-05 14:30  24.2009  24.2600  24.1700  24.2109  24.0784  24.0429
# 42  2019-09-05 14:45  24.2200  24.2850  24.2100  24.2600  24.1201  24.0552
# 43  2019-09-05 15:00  24.2600  24.3900  24.2500  24.2700  24.1539  24.0713
# 44  2019-09-05 15:15  24.2700  24.3200  24.2600  24.2800  24.1870  24.0952
# 45  2019-09-05 15:30  24.2750  24.3800  24.2700  24.3500  24.2176  24.1267
# 46  2019-09-05 15:45  24.3606  24.3800  24.3150  24.3606  24.2539  24.1652
# 47  2019-09-05 16:00  24.3600  24.4150  24.3150  24.3200  24.2814  24.1955
# 48  2019-09-06 09:45  24.6800  24.6800  23.9000  23.9000  24.2439  24.1878
# 49  2019-09-06 10:00  23.9300  24.2700  23.8250  23.9300  24.2088  24.1813
# 50  2019-09-06 10:15  23.9409  24.0950  23.9100  24.0709  24.1852  24.1786
# 51  2019-09-06 10:30  24.0606  24.2435  23.9932  24.1856  24.1746  24.1875
# 52  2019-09-06 10:45  24.2010  24.3100  24.1900  24.3059  24.1779  24.2034
# 53  2019-09-06 11:00  24.2900  24.4800  24.2900  24.4300  24.1879  24.2211
# 54  2019-09-06 11:15  24.4404  24.4800  24.3500  24.3804  24.1903  24.2341
# 55  2019-09-06 11:30  24.3700  24.4620  24.3500  24.3500  24.1941  24.2410
# 56  2019-09-06 11:45  24.3610  24.4934  24.3433  24.4410  24.2617  24.2542
# 57  2019-09-06 12:00  24.4400  24.4850  24.3500  24.3600  24.3155  24.2603
# 58  2019-09-06 12:15  24.3600  24.4200  24.2900  24.3000  24.3441  24.2565
# 59  2019-09-06 12:30  24.3009  24.3228  24.2327  24.2759  24.3554  24.2500
# 60  2019-09-06 12:45  24.2758  24.3639  24.2137  24.3308  24.3585  24.2508
# 61  2019-09-06 13:00  24.3400  24.3500  24.1900  24.2400  24.3348  24.2770
# 62  2019-09-06 13:15  24.2200  24.3000  24.1450  24.1500  24.3060  24.2939
# 63  2019-09-06 13:30  24.1501  24.3000  24.1500  24.2800  24.2972  24.3100
# 64  2019-09-06 13:45  24.2800  24.3000  24.0746  24.1300  24.2583  24.3057
# 65  2019-09-06 14:00  24.1400  24.1637  24.0700  24.1600  24.2333  24.2945
# 66  2019-09-06 14:15  24.1700  24.1850  24.1100  24.1300  24.2121  24.2714
# 67  2019-09-06 14:30  24.1304  24.1509  24.0808  24.1104  24.1914  24.2506
# 68  2019-09-06 14:45  24.1206  24.1600  24.0900  24.1006  24.1626  24.2314
# 69  2019-09-06 15:00  24.1100  24.1100  23.9850  24.0500  24.1389  24.2014
# 70  2019-09-06 15:15  24.0408  24.0786  23.9950  24.0308  24.1240  24.1760
# 71  2019-09-06 15:30  24.0400  24.0600  24.0200  24.0450  24.0946  24.1564
# 72  2019-09-06 15:45  24.0450  24.0550  24.0050  24.0100  24.0796  24.1360
# 73  2019-09-06 16:00  24.0000  24.0199  23.9300  23.9500  24.0533  24.1067
# 74  2019-09-09 09:45  25.6150  25.7600  25.3200  25.5810  24.2347  24.2098
# 75  2019-09-09 10:00  25.5200  25.7250  25.1095  25.2200  24.3734  24.2921
# 76  2019-09-09 10:15  25.2000  25.3600  24.7000  24.7100  24.4496  24.3252
# 77  2019-09-09 10:30  24.7000  25.0900  24.7000  25.0700  24.5771  24.3975
#
#      8<13  Buy      W/L
# 20   True    0      NaN
# 21   True    0      NaN
# 22  False    0      NaN
# 23  False    1  (L, 23)
# 24  False    0      NaN
# 25  False    0      NaN
# 26  False    0      NaN
# 27  False    0      NaN
# 28  False    0      NaN
# 29  False    0      NaN
# 30  False    0      NaN
# 31  False    0      NaN
# 32  False    0      NaN
# 33   True    0      NaN
# 34   True    0      NaN
# 35   True    0      NaN
# 36   True    0      NaN
# 37   True    0      NaN
# 38   True    0      NaN
# 39   True    0      NaN
# 40   True    0      NaN
# 41  False    0      NaN
# 42  False    1  (L, 48)
# 43  False    0      NaN
# 44  False    0      NaN
# 45  False    0      NaN
# 46  False    0      NaN
# 47  False    0      NaN
# 48  False    0      NaN
# 49  False    0      NaN
# 50  False    0      NaN
# 51   True    0      NaN
# 52   True    0      NaN
# 53   True    0      NaN
# 54   True    0      NaN
# 55   True    0      NaN
# 56  False    0      NaN
# 57  False    1  (L, 57)
# 58  False    0      NaN
# 59  False    0      NaN
# 60  False    0      NaN
# 61  False    0      NaN
# 62  False    0      NaN
# 63   True    0      NaN
# 64   True    0      NaN
# 65   True    0      NaN
# 66   True    0      NaN
# 67   True    0      NaN
# 68   True    0      NaN
# 69   True    0      NaN
# 70   True    0      NaN
# 71   True    0      NaN
# 72   True    0      NaN
# 73   True    0      NaN
# 74  False    0      NaN
# 75  False    1  (L, 75)
# 76  False    0      NaN
# 77  False    0      NaN
